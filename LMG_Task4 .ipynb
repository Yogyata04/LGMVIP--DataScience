# %% [markdown]
# # AIM : Image to Pencil Sketch with Python
# # Author : Yogyata Chaubey

# %% [markdown]
# Importing all requrided libraries

# %%
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
from google.colab.patches import *

# %% [markdown]
# Loading and Showing

# %%
image = cv2.imread("/content/drive/MyDrive/sunflower.jpg")
#plt.figure(figsize=(3, 7.195), dpi=50)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=398x612 at 0x7F50400AD750>

# %%
# Converting the image into RGB format

img_rgb=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
cv2_imshow(img_rgb)
# Out:
# <PIL.Image.Image image mode=RGB size=398x612 at 0x7F503FF79510>

# %%
# Converting the image into greyscale

grey_image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
grey_image
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
cv2_imshow(grey_image)
# Out:
# <PIL.Image.Image image mode=L size=398x612 at 0x7F5040061BD0>

# %%
# Converting the image into Inverted Image

inverted_img=255-grey_image
cv2_imshow(inverted_img)
# Out:
# <PIL.Image.Image image mode=L size=398x612 at 0x7F5040062AD0>

# %%
# Converting the image into Gaussian Blur
blurred=cv2.GaussianBlur(inverted_img,(21,21),0)
cv2_imshow(blurred)
# Out:
# <PIL.Image.Image image mode=L size=398x612 at 0x7F503ED1F610>

# %%
# Converting the image into Inverted Blurred

inverted_blurred=255-blurred
cv2_imshow(inverted_blurred)
# Out:
# <PIL.Image.Image image mode=L size=398x612 at 0x7F503EC014E0>

# %%
# Converting the image into Sketch

pencil_sketch=cv2.divide(grey_image,inverted_blurred,scale=256.0)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=398x612 at 0x7F503FF7AB00>
